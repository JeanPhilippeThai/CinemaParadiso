# %%
# Import the libraries neccessary
import requests # call the API
import json # read the pull
import pandas as pd # manipulate the data

# %% [markdown]
# ## Dictionaries

# %%
# API: 3 ways to search for and find movies: /search, /discover and /find (the last one allows to find by IMDB ID)

# %%
# GENRE DICTIONARY: MOVIE
#Action          28
#Adventure       12
#Animation       16
#Comedy          35
#Crime           80
#Documentary     99
#Drama           18
#Family          10751
#Fantasy         14
#History         36
#Horror          27
#Music           10402
#Mystery         9648
#Romance         10749
#Science Fiction 878
#TV Movie        10770
#Thriller        53
#War             10752
#Western         37

# %%
# Languaje codes: https://en.wikipedia.org/wiki/List_of_ISO_639_language_codes

# %%
# List of providers:
tmdb_providers = requests.get('https://api.themoviedb.org/3/watch/providers/movie?api_key=83f0cfd44916bbd39b2d5c5669e79ef3&language=en-GB')

tmdb_providers_json = tmdb_providers.json()

providers = [
    {
        'provider_name': p['provider_name'],
        'provider_id': p['provider_id'],
        'logo_path': p['logo_path']
    }
    for p in tmdb_providers_json['results']
]

df_tmdb_providers_list = pd.DataFrame(providers)

# %%
df_tmdb_providers_list
# Out:
#                      provider_name  provider_id  \
# 0                         Apple TV            2
# 1               Google Play Movies            3
# 2                 Fandango At Home            7
# 3                          Netflix            8
# 4               Amazon Prime Video            9
# ..                             ...          ...
# 740  Toei On Demand Amazon Channel         2520
# 741                  Cranked Up TV         2523
# 742             Super Channel Plus         2525
# 743  Made in Europe Amazon Channel         2526
# 744             AroVision Aotearoa         2527
#
#                             logo_path
# 0    /9ghgSC0MA082EL6HLCW3GalykFD.jpg
# 1    /8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg
# 2    /19fkcOz0xeUgCVW8tO85uOYnYK9.jpg
# 3    /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg
# 4    /pvske1MyAoymrs5bguRfVqYiM9a.jpg
# ..                                ...
# 740  /8ocaYkrXCZklGKAWUyGi03jtBxU.jpg
# 741  /eP7469ZXfQDZnnLcCiHAeSPMbRI.jpg
# ...

# %%
df_tmdb_providers_list[df_tmdb_providers_list['provider_name'] == 'Amazon Prime Video']
# Out:
#          provider_name  provider_id                         logo_path
# 4   Amazon Prime Video            9  /pvske1MyAoymrs5bguRfVqYiM9a.jpg
# 53  Amazon Prime Video          119  /pvske1MyAoymrs5bguRfVqYiM9a.jpg

# %% [markdown]
# # NETFLIX DATASET EXRTACTION

# %%
# Import data from the webpage with the API key
netflix_json = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=83f0cfd44916bbd39b2d5c5669e79ef3&with_watch_providers=8&watch_region=GB').json()

# %%
# Retrieving information from the results section from the first page
netflix = netflix_json["results"]

# %%
# Retrieving information from all pages by a loop
for page in range(2, netflix_json["total_pages"]+1):
    netflix_json = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=83f0cfd44916bbd39b2d5c5669e79ef3&with_watch_providers=8&watch_region=GB' + f"&page={page}").json()
    netflix.extend(netflix_json["results"])

# %%
# Convert the database into a dataframe
netflix_df = pd.DataFrame(data=netflix, columns=['title', 'id', 'vote_average', 'vote_count', 'original_language','genre_ids','popularity','release_date'])

# %%
# Save the file to csv
netflix_df.to_csv('netflix_movies.csv', index=False)

# %%
netflix_df.head(3)
# Out:
#                     title       id  vote_average  vote_count  \
# 0                Sikandar  1257960         5.100          47
# 1  Spider-Man: Homecoming   315635         7.331       22237
# 2            Ready or Not   567609         7.035        4807
#
#   original_language          genre_ids  popularity release_date
# 0                hi           [28, 18]    218.9206   2025-03-29
# 1                en  [28, 12, 878, 18]    165.7082   2017-07-05
# 2                en           [27, 35]    114.9843   2019-08-21

# %% [markdown]
# # BFI Player DATASET EXRTACTION

# %%
# Import data from the webpage with the API key
bfi_json = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=83f0cfd44916bbd39b2d5c5669e79ef3&with_watch_providers=224&watch_region=GB').json()

# %%
# Retrieving information from the results section from the first page
bfi = bfi_json["results"]

# %%
# Retrieving information from all pages by a loop
for page in range(2, bfi_json["total_pages"]+1):
    bfi_json = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=83f0cfd44916bbd39b2d5c5669e79ef3&with_watch_providers=224&watch_region=GB' + f"&page={page}").json()
    bfi.extend(bfi_json["results"])

# %%
# Convert the database into a dataframe
bfi_df = pd.DataFrame(data=bfi, columns=['title', 'id', 'vote_average', 'vote_count', 'original_language','genre_ids','popularity','release_date'])

# %%
bfi_df.to_csv('bfi_movies.csv', index=False)

# %%
bfi_df.head(3)
# Out:
#                    title       id  vote_average  vote_count original_language  \
# 0               Parasite   496243         8.500       19102                ko
# 1  Manchester by the Sea   334541         7.546        6018                en
# 2        The Balconettes  1112466         6.438          56                fr
#
#       genre_ids  popularity release_date
# 0  [35, 53, 18]    108.3050   2019-05-30
# 1          [18]     59.6534   2016-11-17
# 2  [35, 27, 14]     52.0199   2024-11-15
